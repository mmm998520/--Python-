# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
ps = np.random.randn(50)
ps
# Out:
# array([ 0.40624654, -0.33852257,  0.63363145, -0.00694842,  0.52812736,
#         0.15989912,  0.98656989, -0.839116  ,  0.12372195, -0.20104784,
#        -0.18621556, -0.01776841, -1.1092662 ,  0.26023636,  1.35608667,
#        -0.2307982 ,  0.03884076,  0.0254703 ,  0.86372436,  0.53832969,
#        -0.45812996, -1.05302773,  1.92346205, -0.1102035 ,  1.35943699,
#        -0.76519002,  0.65670282, -0.39494411, -1.08751905,  1.40237047,
#         0.0686114 , -0.98928926, -0.43249552,  0.60711954,  0.55327704,
#         0.32382413,  0.24265434,  0.14479899, -0.23772346,  0.13125578,
#         1.02831031,  0.40505008, -0.43221443,  0.31535981, -0.20652352,
#         0.86468521,  0.34051694, -0.35943555,  0.63629324, -0.32038535])

# %%
plt.plot(ps)

# %%
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x)

# %%
plt.plot(x,np.sin(x))

# %%
plt.plot(x,np.sin(x)+x)

# %% [markdown]
# ## 繪圖時，xy要相互對應，一個x必有一個對應的y

# %%
plt.plot(x,np.linspace(4,7,99))
# Out:
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# <ipython-input-13-d4150bed4d1a> in <module>
# ----> 1 plt.plot(x,np.linspace(4,7,99))
#
# /data/data/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# /data/data/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ...

# %%
plt.plot(x,np.linspace(4,7,100))

# %% [markdown]
# ## 可以同時畫兩條線

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.tan(x))
